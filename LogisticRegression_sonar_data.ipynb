# %% [markdown]
# <a href="https://colab.research.google.com/github/CSpanias/ml_training/blob/master/LogisticRegression(sonar_data).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Machine Learning - Logistic Regression**
# *by [CSpanias](https://github.com/CSpanias), 12/12/2021*

# %% [markdown]
# This notebook was developed as a training script.
#
# It is based on:
# * [SONAR Rock vs Mine Prediction with Python](https://www.youtube.com/watch?v=fiz1ORTBGpY&list=PLfFghEzKVmjvuSA67LszN1dZ-Dd_pkus6)
#
# The goal was to practice the logistic regression and improve the model developed in the above tutorial.
#
# Things added:
# 1. [Multi-collinearity check](#MC)
# 2. [K-Fold Cross-Validation](#KFCV)
# 3. [Hyperparameter Optimization](#GS)
# 4. [Confusion Matrix](#CM)

# %%
import pandas as pd
import numpy as np
import seaborn as sns

from matplotlib import pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, accuracy_score, f1_score, make_scorer
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import KFold, cross_validate, cross_val_score
from sklearn.model_selection import cross_val_predict, GridSearchCV

# %%
# import dataset without headers
df = pd.read_csv("https://raw.githubusercontent.com/CSpanias/ml_training/master/sonar_data.csv", header=None)

# %% [markdown]
# <a name="DataPreProcessing"> </a>
# # **Data PreProcessing**

# %%
# print the first 5 rows of data
df.head()
# Out:
#        0       1       2       3       4   ...      56      57      58      59  60
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  ...  0.0180  0.0084  0.0090  0.0032   R
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  ...  0.0140  0.0049  0.0052  0.0044   R
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  ...  0.0316  0.0164  0.0095  0.0078   R
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  ...  0.0050  0.0044  0.0040  0.0117   R
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  ...  0.0072  0.0048  0.0107  0.0094   R
#
# [5 rows x 61 columns]

# %%
# check data types, size, and null-values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       208 non-null    float64
#  1   1       208 non-null    float64
#  2   2       208 non-null    float64
#  3   3       208 non-null    float64
#  4   4       208 non-null    float64
#  5   5       208 non-null    float64
#  6   6       208 non-null    float64
#  7   7       208 non-null    float64
#  8   8       208 non-null    float64
#  9   9       208 non-null    float64
#  10  10      208 non-null    float64
#  11  11      208 non-null    float64
#  12  12      208 non-null    float64
#  13  13      208 non-null    float64
#  14  14      208 non-null    float64
#  15  15      208 non-null    float64
#  16  16      208 non-null    float64
#  17  17      208 non-null    float64
#  18  18      208 non-null    float64
#  19  19      208 non-null    float64
#  20  20      208 non-null    float64
#  21  21      208 non-null    float64
#  22  22      208 non-null    float64
#  23  23      208 non-null    float64
#  24  24      208 non-null    float64
#  25  25      208 non-null    float64
#  26  26      208 non-null    float64
#  27  27      208 non-null    float64
#  28  28      208 non-null    float64
#  29  29      208 non-null    float64
#  30  30      208 non-null    float64
#  31  31      208 non-null    float64
#  32  32      208 non-null    float64
#  33  33      208 non-null    float64
#  34  34      208 non-null    float64
#  35  35      208 non-null    float64
#  36  36      208 non-null    float64
#  37  37      208 non-null    float64
#  38  38      208 non-null    float64
#  39  39      208 non-null    float64
#  40  40      208 non-null    float64
#  41  41      208 non-null    float64
#  42  42      208 non-null    float64
#  43  43      208 non-null    float64
#  44  44      208 non-null    float64
#  45  45      208 non-null    float64
#  46  46      208 non-null    float64
#  47  47      208 non-null    float64
#  48  48      208 non-null    float64
#  49  49      208 non-null    float64
#  50  50      208 non-null    float64
#  51  51      208 non-null    float64
#  52  52      208 non-null    float64
#  53  53      208 non-null    float64
#  54  54      208 non-null    float64
#  55  55      208 non-null    float64
#  56  56      208 non-null    float64
#  57  57      208 non-null    float64
#  58  58      208 non-null    float64
#  59  59      208 non-null    float64
#  60  60      208 non-null    object
# dtypes: float64(60), object(1)
# memory usage: 99.2+ KB

# %%
# number of rows and columns
df.shape
# Out:
# (208, 61)

# %%
# get basic statistical data
df.describe()
# Out:
#                0           1           2   ...          57          58          59
# count  208.000000  208.000000  208.000000  ...  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832  ...    0.007949    0.007941    0.006507
# std      0.022991    0.032960    0.038428  ...    0.006470    0.006181    0.005031
# min      0.001500    0.000600    0.001500  ...    0.000300    0.000100    0.000600
# 25%      0.013350    0.016450    0.018950  ...    0.003600    0.003675    0.003100
# 50%      0.022800    0.030800    0.034300  ...    0.005800    0.006400    0.005300
# 75%      0.035550    0.047950    0.057950  ...    0.010350    0.010325    0.008525
# max      0.137100    0.233900    0.305900  ...    0.044000    0.036400    0.043900
#
# [8 rows x 60 columns]

# %%
# check for missing data
df.isnull().sum()
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 56    0
# 57    0
# 58    0
# 59    0
# 60    0
# Length: 61, dtype: int64

# %%
# check how many different labels there are
print(df[60].unique())
print("")
# check target labels (M = mine, R = rock)
df[60].value_counts()
# Out:
# ['R' 'M']
# M    111
# R     97
# Name: 60, dtype: int64

# %% [markdown]
# <a name="MC"> </a>
# Check for highly-correlated values:

# %%
# check for multi-collinearity
df.corr()
# Out:
#           0         1         2   ...        57        58        59
# 0   1.000000  0.735896  0.571537  ...  0.368132  0.357116  0.347078
# 1   0.735896  1.000000  0.779916  ...  0.353042  0.352200  0.358761
# 2   0.571537  0.779916  1.000000  ...  0.334108  0.425047  0.373948
# 3   0.491438  0.606684  0.781786  ...  0.344865  0.420266  0.400626
# 4   0.344797  0.419669  0.546141  ...  0.238793  0.290982  0.253710
# 5   0.238921  0.332329  0.346275  ...  0.203986  0.220573  0.178158
# 6   0.260815  0.279040  0.190434  ...  0.242646  0.183578  0.222493
# 7   0.355523  0.334615  0.237884  ...  0.287603  0.194400  0.146216
# 8   0.353420  0.316733  0.252691  ...  0.231745  0.097293  0.095243
# 9   0.318276  0.270782  0.219637  ...  0.212277  0.058273  0.097358
# 10  0.344058  0.297065  0.274610  ...  0.193358  0.067726  0.089695
# 11  0.210861  0.194102  0.214807  ...  0.065273  0.044614  0.071364
# 12  0.210722  0.249596  0.258767  ...  0.171140  0.151804  0.061411
# 13  0.256278  0.273170  0.291724  ...  0.258675  0.209122  0.120966
# 14  0.304878  0.307599  0.285663  ...  0.225545  0.193671  0.171089
# 15  0.239079  0.261844  0.237017  ...  0.198019  0.182337  0.158438
# 16  0.137845  0.152170  0.201093  ...  0.148563  0.121800  0.093992
# 17  0.041817  0.042870  0.120587  ...  0.096022  0.028446  0.046617
# 18  0.055227  0.040911  0.099303  ...  0.138365  0.023019  0.007468
# 19  0.156760  0.102428  0.103117  ...  0.132453 -0.005364 -0.028540
# 20  0.117663  0.075255  0.063990  ...  0.079818 -0.049413 -0.025201
# 21 -0.056973 -0.074157 -0.026815  ... -0.035829 -0.143209 -0.085696
# 22 -0.163426 -0.179365 -0.073400  ... -0.105235 -0.168149 -0.163696
# 23 -0.218093 -0.196469 -0.085380  ... -0.210556 -0.186527 -0.190877
# 24 -0.295683 -0.295302 -0.214256  ... -0.270222 -0.303155 -0.253233
# 25 -0.342865 -0.365749 -0.291974  ... -0.303427 -0.385725 -0.303949
# 26 -0.341703 -0.337046 -0.263111  ... -0.321868 -0.360340 -0.267596
# 27 -0.224340 -0.234386 -0.256674  ... -0.261443 -0.275442 -0.195130
# 28 -0.199099 -0.228490 -0.290728  ... -0.267938 -0.247318 -0.203776
# 29 -0.077430 -0.115301 -0.197493  ... -0.134302 -0.129402 -0.076100
# 30 -0.048370 -0.055862 -0.106198  ... -0.036092 -0.044197 -0.043015
# 31 -0.030444 -0.049683 -0.109895  ...  0.018564  0.013499 -0.023863
# 32 -0.031939 -0.108272 -0.170671  ...  0.003712  0.054285 -0.015804
# 33  0.031319 -0.004247 -0.099409  ...  0.083192  0.138214  0.075686
# 34  0.098118  0.115824  0.017053  ...  0.143897  0.227783  0.191193
# 35  0.080722  0.132611  0.053070  ...  0.106275  0.222683  0.176982
# 36  0.119565  0.169186  0.107530  ...  0.110760  0.163162  0.166263
# 37  0.209873  0.217494  0.130276  ...  0.169710  0.206001  0.233288
# 38  0.208371  0.186828  0.110499  ...  0.218912  0.231150  0.222611
# 39  0.099993  0.098350  0.074137  ...  0.143718  0.189058  0.202034
# 40  0.127313  0.188226  0.189047  ...  0.196282  0.304521  0.281889
# 41  0.213592  0.261345  0.233442  ...  0.201077  0.276762  0.220597
# 42  0.206057  0.186368  0.113920  ...  0.210814  0.199334  0.161416
# 43  0.157949  0.133018  0.071946  ...  0.109166  0.154547  0.108190
# 44  0.279968  0.285716  0.180734  ...  0.167337  0.178402  0.157181
# 45  0.319354  0.304247  0.173649  ...  0.237890  0.205291  0.180691
# 46  0.230343  0.255797  0.179528  ...  0.240471  0.209045  0.139727
# 47  0.203234  0.265279  0.234896  ...  0.270198  0.221425  0.123666
# 48  0.247560  0.313995  0.223074  ...  0.328238  0.209152  0.088640
# 49  0.269287  0.245868  0.081096  ...  0.342866  0.178118  0.139944
# 50  0.254450  0.320538  0.238110  ...  0.325665  0.317942  0.246764
# 51  0.355299  0.434548  0.394076  ...  0.309673  0.298711  0.195379
# 52  0.311729  0.346076  0.332914  ...  0.370764  0.346095  0.280780
# 53  0.322299  0.383960  0.367186  ...  0.404117  0.447118  0.283471
# 54  0.312067  0.380165  0.289731  ...  0.503465  0.453658  0.264399
# 55  0.220642  0.262263  0.287661  ...  0.463659  0.430804  0.349449
# 56  0.313725  0.280341  0.380819  ...  0.509805  0.431295  0.287219
# 57  0.368132  0.353042  0.334108  ...  1.000000  0.550235  0.329827
# 58  0.357116  0.352200  0.425047  ...  0.550235  1.000000  0.642872
# 59  0.347078  0.358761  0.373948  ...  0.329827  0.642872  1.000000
#
# [60 rows x 60 columns]

# %%
# remove high correlated values
df.drop(columns=[9, 14, 15], axis=1, inplace=True)
# check shape
df.shape
# Out:
# (208, 58)

# %%
# mean value per label
df.groupby(60).mean()
# Out:
#           0         1         2   ...        57        58        59
# 60                                ...
# M   0.034989  0.045544  0.050720  ...  0.009060  0.008695  0.006930
# R   0.022498  0.030303  0.035951  ...  0.006677  0.007078  0.006024
#
# [2 rows x 57 columns]

# %%
# seperating data and lables
X = df.drop(columns=60, axis=1)
y = df[60]

# %%
# check that the shape looks OK
print(X.shape)
print(y.shape)
# Out:
# (208, 57)
# (208,)

# %% [markdown]
# <a name="KFCV"> </a>
# # **Model Training & Evalution Process**
# * Replaced train_test_split with cross_validation for a more objective accuracy estimate

# %%
# split training and test data using cross-validation
kf = KFold(n_splits=10, shuffle=True)

# %%
# select algorithm
model = LogisticRegression()

# %% [markdown]
# <a name="GS"> </a>
# # **Hyperparameter Optimization**

# %%
# declare parameters for hyperparameter tuning
params = [
          {
          'C': [0.1, 1, 10, 15, 20],
          'fit_intercept':['True', 'False'],
          'solver': ['liblinear'],
           'max_iter': [10, 100, 200, 500, 1000],
           'multi_class': ['auto', 'ovr'],
           },
          ]

# create the grid search object
gs = GridSearchCV(model, params, scoring='accuracy', cv=kf,
                  return_train_score=True, verbose=3)

# fit the gs object
gs.fit(X, y)
# Out:
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# [CV 1/10] END C=0.1, fit_intercept=True, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.738, test=0.762) total time=   0.0s
# [CV 2/10] END C=0.1, fit_intercept=True, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.727, test=0.714) total time=   0.0s
# [CV 3/10] END C=0.1, fit_intercept=True, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.701, test=0.619) total time=   0.0s
# [CV 4/10] END C=0.1, fit_intercept=True, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.738, test=0.571) total time=   0.0s
# [CV 5/10] END C=0.1, fit_intercept=True, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.722, test=0.810) total time=   0.0s
# [CV 6/10] END C=0.1, fit_intercept=True, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.727, test=0.762) total time=   0.1s
# [CV 7/10] END C=0.1, fit_intercept=True, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.711, test=0.524) total time=   0.0s
# [CV 8/10] END C=0.1, fit_intercept=True, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.733, test=0.762) total time=   0.0s
# [CV 9/10] END C=0.1, fit_intercept=True, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.750, test=0.700) total time=   0.1s
# [CV 10/10] END C=0.1, fit_intercept=True, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.718, test=0.750) total time=   0.0s
# [CV 1/10] END C=0.1, fit_intercept=True, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.738, test=0.762) total time=   0.0s
# [CV 2/10] END C=0.1, fit_intercept=True, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.727, test=0.714) total time=   0.0s
# [CV 3/10] END C=0.1, fit_intercept=True, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.701, test=0.619) total time=   0.0s
# [CV 4/10] END C=0.1, fit_intercept=True, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.738, test=0.571) total time=   0.0s
# [CV 5/10] END C=0.1, fit_intercept=True, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.722, test=0.810) total time=   0.0s
# [CV 6/10] END C=0.1, fit_intercept=True, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.727, test=0.762) total time=   0.0s
# [CV 7/10] END C=0.1, fit_intercept=True, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.711, test=0.524) total time=   0.0s
# [CV 8/10] END C=0.1, fit_intercept=True, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.733, test=0.762) total time=   0.0s
# [CV 9/10] END C=0.1, fit_intercept=True, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.750, test=0.700) total time=   0.0s
# [CV 10/10] END C=0.1, fit_intercept=True, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.718, test=0.750) total time=   0.0s
# [CV 1/10] END C=0.1, fit_intercept=True, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.738, test=0.762) total time=   0.0s
# [CV 2/10] END C=0.1, fit_intercept=True, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.727, test=0.714) total time=   0.0s
# [CV 3/10] END C=0.1, fit_intercept=True, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.701, test=0.619) total time=   0.0s
# [CV 4/10] END C=0.1, fit_intercept=True, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.738, test=0.571) total time=   0.0s
# [CV 5/10] END C=0.1, fit_intercept=True, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.722, test=0.810) total time=   0.0s
# [CV 6/10] END C=0.1, fit_intercept=True, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.727, test=0.762) total time=   0.0s
# [CV 7/10] END C=0.1, fit_intercept=True, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.711, test=0.524) total time=   0.0s
# [CV 8/10] END C=0.1, fit_intercept=True, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.733, test=0.762) total time=   0.0s
# [CV 9/10] END C=0.1, fit_intercept=True, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.750, test=0.700) total time=   0.0s
# [CV 10/10] END C=0.1, fit_intercept=True, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.718, test=0.750) total time=   0.0s
# [CV 1/10] END C=0.1, fit_intercept=True, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.738, test=0.762) total time=   0.0s
# [CV 2/10] END C=0.1, fit_intercept=True, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.727, test=0.714) total time=   0.0s
# [CV 3/10] END C=0.1, fit_intercept=True, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.701, test=0.619) total time=   0.0s
# [CV 4/10] END C=0.1, fit_intercept=True, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.738, test=0.571) total time=   0.0s
# [CV 5/10] END C=0.1, fit_intercept=True, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.722, test=0.810) total time=   0.0s
# [CV 6/10] END C=0.1, fit_intercept=True, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.727, test=0.762) total time=   0.0s
# [CV 7/10] END C=0.1, fit_intercept=True, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.711, test=0.524) total time=   0.0s
# [CV 8/10] END C=0.1, fit_intercept=True, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.733, test=0.762) total time=   0.0s
# [CV 9/10] END C=0.1, fit_intercept=True, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.750, test=0.700) total time=   0.0s
# [CV 10/10] END C=0.1, fit_intercept=True, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.718, test=0.750) total time=   0.0s
# [CV 1/10] END C=0.1, fit_intercept=True, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.738, test=0.762) total time=   0.0s
# [CV 2/10] END C=0.1, fit_intercept=True, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.727, test=0.714) total time=   0.0s
# [CV 3/10] END C=0.1, fit_intercept=True, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.701, test=0.619) total time=   0.0s
# [CV 4/10] END C=0.1, fit_intercept=True, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.738, test=0.571) total time=   0.0s
# [CV 5/10] END C=0.1, fit_intercept=True, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.722, test=0.810) total time=   0.0s
# [CV 6/10] END C=0.1, fit_intercept=True, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.727, test=0.762) total time=   0.0s
# [CV 7/10] END C=0.1, fit_intercept=True, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.711, test=0.524) total time=   0.0s
# [CV 8/10] END C=0.1, fit_intercept=True, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.733, test=0.762) total time=   0.0s
# [CV 9/10] END C=0.1, fit_intercept=True, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.750, test=0.700) total time=   0.0s
# [CV 10/10] END C=0.1, fit_intercept=True, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.718, test=0.750) total time=   0.0s
# [CV 1/10] END C=0.1, fit_intercept=True, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.738, test=0.762) total time=   0.0s
# [CV 2/10] END C=0.1, fit_intercept=True, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.727, test=0.714) total time=   0.0s
# [CV 3/10] END C=0.1, fit_intercept=True, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.701, test=0.619) total time=   0.0s
# [CV 4/10] END C=0.1, fit_intercept=True, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.738, test=0.571) total time=   0.0s
# [CV 5/10] END C=0.1, fit_intercept=True, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.722, test=0.810) total time=   0.0s
# [CV 6/10] END C=0.1, fit_intercept=True, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.727, test=0.762) total time=   0.0s
# [CV 7/10] END C=0.1, fit_intercept=True, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.711, test=0.524) total time=   0.0s
# [CV 8/10] END C=0.1, fit_intercept=True, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.733, test=0.762) total time=   0.0s
# [CV 9/10] END C=0.1, fit_intercept=True, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.750, test=0.700) total time=   0.0s
# [CV 10/10] END C=0.1, fit_intercept=True, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.718, test=0.750) total time=   0.0s
# [CV 1/10] END C=0.1, fit_intercept=True, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.738, test=0.762) total time=   0.0s
# [CV 2/10] END C=0.1, fit_intercept=True, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.727, test=0.714) total time=   0.0s
# [CV 3/10] END C=0.1, fit_intercept=True, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.701, test=0.619) total time=   0.0s
# [CV 4/10] END C=0.1, fit_intercept=True, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.738, test=0.571) total time=   0.0s
# [CV 5/10] END C=0.1, fit_intercept=True, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.722, test=0.810) total time=   0.0s
# [CV 6/10] END C=0.1, fit_intercept=True, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.727, test=0.762) total time=   0.0s
# [CV 7/10] END C=0.1, fit_intercept=True, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.711, test=0.524) total time=   0.0s
# [CV 8/10] END C=0.1, fit_intercept=True, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.733, test=0.762) total time=   0.0s
# [CV 9/10] END C=0.1, fit_intercept=True, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.750, test=0.700) total time=   0.0s
# [CV 10/10] END C=0.1, fit_intercept=True, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.718, test=0.750) total time=   0.0s
# [CV 1/10] END C=0.1, fit_intercept=True, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.738, test=0.762) total time=   0.0s
# [CV 2/10] END C=0.1, fit_intercept=True, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.727, test=0.714) total time=   0.0s
# [CV 3/10] END C=0.1, fit_intercept=True, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.701, test=0.619) total time=   0.0s
# [CV 4/10] END C=0.1, fit_intercept=True, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.738, test=0.571) total time=   0.0s
# [CV 5/10] END C=0.1, fit_intercept=True, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.722, test=0.810) total time=   0.0s
# [CV 6/10] END C=0.1, fit_intercept=True, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.727, test=0.762) total time=   0.0s
# [CV 7/10] END C=0.1, fit_intercept=True, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.711, test=0.524) total time=   0.0s
# [CV 8/10] END C=0.1, fit_intercept=True, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.733, test=0.762) total time=   0.0s
# [CV 9/10] END C=0.1, fit_intercept=True, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.750, test=0.700) total time=   0.0s
# [CV 10/10] END C=0.1, fit_intercept=True, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.718, test=0.750) total time=   0.0s
# [CV 1/10] END C=0.1, fit_intercept=True, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.738, test=0.762) total time=   0.0s
# [CV 2/10] END C=0.1, fit_intercept=True, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.727, test=0.714) total time=   0.0s
# [CV 3/10] END C=0.1, fit_intercept=True, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.701, test=0.619) total time=   0.0s
# [CV 4/10] END C=0.1, fit_intercept=True, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.738, test=0.571) total time=   0.0s
# [CV 5/10] END C=0.1, fit_intercept=True, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.722, test=0.810) total time=   0.0s
# [CV 6/10] END C=0.1, fit_intercept=True, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.727, test=0.762) total time=   0.0s
# [CV 7/10] END C=0.1, fit_intercept=True, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.711, test=0.524) total time=   0.0s
# [CV 8/10] END C=0.1, fit_intercept=True, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.733, test=0.762) total time=   0.0s
# [CV 9/10] END C=0.1, fit_intercept=True, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.750, test=0.700) total time=   0.0s
# [CV 10/10] END C=0.1, fit_intercept=True, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.718, test=0.750) total time=   0.0s
# [CV 1/10] END C=0.1, fit_intercept=True, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.738, test=0.762) total time=   0.0s
# [CV 2/10] END C=0.1, fit_intercept=True, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.727, test=0.714) total time=   0.0s
# [CV 3/10] END C=0.1, fit_intercept=True, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.701, test=0.619) total time=   0.0s
# [CV 4/10] END C=0.1, fit_intercept=True, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.738, test=0.571) total time=   0.0s
# [CV 5/10] END C=0.1, fit_intercept=True, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.722, test=0.810) total time=   0.0s
# [CV 6/10] END C=0.1, fit_intercept=True, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.727, test=0.762) total time=   0.0s
# [CV 7/10] END C=0.1, fit_intercept=True, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.711, test=0.524) total time=   0.0s
# [CV 8/10] END C=0.1, fit_intercept=True, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.733, test=0.762) total time=   0.0s
# [CV 9/10] END C=0.1, fit_intercept=True, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.750, test=0.700) total time=   0.0s
# [CV 10/10] END C=0.1, fit_intercept=True, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.718, test=0.750) total time=   0.0s
# [CV 1/10] END C=0.1, fit_intercept=False, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.738, test=0.762) total time=   0.0s
# [CV 2/10] END C=0.1, fit_intercept=False, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.727, test=0.714) total time=   0.0s
# [CV 3/10] END C=0.1, fit_intercept=False, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.701, test=0.619) total time=   0.0s
# [CV 4/10] END C=0.1, fit_intercept=False, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.738, test=0.571) total time=   0.0s
# [CV 5/10] END C=0.1, fit_intercept=False, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.722, test=0.810) total time=   0.0s
# [CV 6/10] END C=0.1, fit_intercept=False, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.727, test=0.762) total time=   0.0s
# [CV 7/10] END C=0.1, fit_intercept=False, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.711, test=0.524) total time=   0.0s
# [CV 8/10] END C=0.1, fit_intercept=False, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.733, test=0.762) total time=   0.0s
# [CV 9/10] END C=0.1, fit_intercept=False, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.750, test=0.700) total time=   0.0s
# [CV 10/10] END C=0.1, fit_intercept=False, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.718, test=0.750) total time=   0.0s
# [CV 1/10] END C=0.1, fit_intercept=False, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.738, test=0.762) total time=   0.0s
# [CV 2/10] END C=0.1, fit_intercept=False, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.727, test=0.714) total time=   0.0s
# [CV 3/10] END C=0.1, fit_intercept=False, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.701, test=0.619) total time=   0.0s
# [CV 4/10] END C=0.1, fit_intercept=False, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.738, test=0.571) total time=   0.0s
# [CV 5/10] END C=0.1, fit_intercept=False, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.722, test=0.810) total time=   0.0s
# [CV 6/10] END C=0.1, fit_intercept=False, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.727, test=0.762) total time=   0.0s
# [CV 7/10] END C=0.1, fit_intercept=False, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.711, test=0.524) total time=   0.0s
# [CV 8/10] END C=0.1, fit_intercept=False, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.733, test=0.762) total time=   0.0s
# [CV 9/10] END C=0.1, fit_intercept=False, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.750, test=0.700) total time=   0.0s
# [CV 10/10] END C=0.1, fit_intercept=False, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.718, test=0.750) total time=   0.0s
# [CV 1/10] END C=0.1, fit_intercept=False, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.738, test=0.762) total time=   0.0s
# [CV 2/10] END C=0.1, fit_intercept=False, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.727, test=0.714) total time=   0.0s
# [CV 3/10] END C=0.1, fit_intercept=False, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.701, test=0.619) total time=   0.0s
# [CV 4/10] END C=0.1, fit_intercept=False, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.738, test=0.571) total time=   0.0s
# [CV 5/10] END C=0.1, fit_intercept=False, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.722, test=0.810) total time=   0.0s
# [CV 6/10] END C=0.1, fit_intercept=False, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.727, test=0.762) total time=   0.0s
# [CV 7/10] END C=0.1, fit_intercept=False, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.711, test=0.524) total time=   0.0s
# [CV 8/10] END C=0.1, fit_intercept=False, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.733, test=0.762) total time=   0.0s
# [CV 9/10] END C=0.1, fit_intercept=False, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.750, test=0.700) total time=   0.0s
# [CV 10/10] END C=0.1, fit_intercept=False, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.718, test=0.750) total time=   0.0s
# [CV 1/10] END C=0.1, fit_intercept=False, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.738, test=0.762) total time=   0.0s
# [CV 2/10] END C=0.1, fit_intercept=False, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.727, test=0.714) total time=   0.0s
# [CV 3/10] END C=0.1, fit_intercept=False, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.701, test=0.619) total time=   0.0s
# [CV 4/10] END C=0.1, fit_intercept=False, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.738, test=0.571) total time=   0.0s
# [CV 5/10] END C=0.1, fit_intercept=False, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.722, test=0.810) total time=   0.0s
# [CV 6/10] END C=0.1, fit_intercept=False, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.727, test=0.762) total time=   0.0s
# [CV 7/10] END C=0.1, fit_intercept=False, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.711, test=0.524) total time=   0.0s
# [CV 8/10] END C=0.1, fit_intercept=False, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.733, test=0.762) total time=   0.0s
# [CV 9/10] END C=0.1, fit_intercept=False, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.750, test=0.700) total time=   0.0s
# [CV 10/10] END C=0.1, fit_intercept=False, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.718, test=0.750) total time=   0.0s
# [CV 1/10] END C=0.1, fit_intercept=False, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.738, test=0.762) total time=   0.0s
# [CV 2/10] END C=0.1, fit_intercept=False, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.727, test=0.714) total time=   0.0s
# [CV 3/10] END C=0.1, fit_intercept=False, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.701, test=0.619) total time=   0.0s
# [CV 4/10] END C=0.1, fit_intercept=False, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.738, test=0.571) total time=   0.0s
# [CV 5/10] END C=0.1, fit_intercept=False, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.722, test=0.810) total time=   0.0s
# [CV 6/10] END C=0.1, fit_intercept=False, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.727, test=0.762) total time=   0.0s
# [CV 7/10] END C=0.1, fit_intercept=False, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.711, test=0.524) total time=   0.0s
# [CV 8/10] END C=0.1, fit_intercept=False, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.733, test=0.762) total time=   0.0s
# [CV 9/10] END C=0.1, fit_intercept=False, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.750, test=0.700) total time=   0.0s
# [CV 10/10] END C=0.1, fit_intercept=False, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.718, test=0.750) total time=   0.0s
# [CV 1/10] END C=0.1, fit_intercept=False, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.738, test=0.762) total time=   0.0s
# [CV 2/10] END C=0.1, fit_intercept=False, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.727, test=0.714) total time=   0.0s
# [CV 3/10] END C=0.1, fit_intercept=False, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.701, test=0.619) total time=   0.0s
# [CV 4/10] END C=0.1, fit_intercept=False, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.738, test=0.571) total time=   0.0s
# [CV 5/10] END C=0.1, fit_intercept=False, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.722, test=0.810) total time=   0.0s
# [CV 6/10] END C=0.1, fit_intercept=False, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.727, test=0.762) total time=   0.0s
# [CV 7/10] END C=0.1, fit_intercept=False, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.711, test=0.524) total time=   0.0s
# [CV 8/10] END C=0.1, fit_intercept=False, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.733, test=0.762) total time=   0.0s
# [CV 9/10] END C=0.1, fit_intercept=False, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.750, test=0.700) total time=   0.0s
# [CV 10/10] END C=0.1, fit_intercept=False, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.718, test=0.750) total time=   0.0s
# [CV 1/10] END C=0.1, fit_intercept=False, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.738, test=0.762) total time=   0.0s
# [CV 2/10] END C=0.1, fit_intercept=False, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.727, test=0.714) total time=   0.0s
# [CV 3/10] END C=0.1, fit_intercept=False, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.701, test=0.619) total time=   0.0s
# [CV 4/10] END C=0.1, fit_intercept=False, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.738, test=0.571) total time=   0.0s
# [CV 5/10] END C=0.1, fit_intercept=False, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.722, test=0.810) total time=   0.0s
# [CV 6/10] END C=0.1, fit_intercept=False, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.727, test=0.762) total time=   0.0s
# [CV 7/10] END C=0.1, fit_intercept=False, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.711, test=0.524) total time=   0.0s
# [CV 8/10] END C=0.1, fit_intercept=False, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.733, test=0.762) total time=   0.0s
# [CV 9/10] END C=0.1, fit_intercept=False, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.750, test=0.700) total time=   0.0s
# [CV 10/10] END C=0.1, fit_intercept=False, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.718, test=0.750) total time=   0.0s
# [CV 1/10] END C=0.1, fit_intercept=False, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.738, test=0.762) total time=   0.0s
# [CV 2/10] END C=0.1, fit_intercept=False, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.727, test=0.714) total time=   0.0s
# [CV 3/10] END C=0.1, fit_intercept=False, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.701, test=0.619) total time=   0.0s
# [CV 4/10] END C=0.1, fit_intercept=False, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.738, test=0.571) total time=   0.0s
# [CV 5/10] END C=0.1, fit_intercept=False, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.722, test=0.810) total time=   0.0s
# [CV 6/10] END C=0.1, fit_intercept=False, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.727, test=0.762) total time=   0.0s
# [CV 7/10] END C=0.1, fit_intercept=False, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.711, test=0.524) total time=   0.0s
# [CV 8/10] END C=0.1, fit_intercept=False, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.733, test=0.762) total time=   0.0s
# [CV 9/10] END C=0.1, fit_intercept=False, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.750, test=0.700) total time=   0.0s
# [CV 10/10] END C=0.1, fit_intercept=False, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.718, test=0.750) total time=   0.0s
# [CV 1/10] END C=0.1, fit_intercept=False, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.738, test=0.762) total time=   0.0s
# [CV 2/10] END C=0.1, fit_intercept=False, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.727, test=0.714) total time=   0.0s
# [CV 3/10] END C=0.1, fit_intercept=False, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.701, test=0.619) total time=   0.0s
# [CV 4/10] END C=0.1, fit_intercept=False, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.738, test=0.571) total time=   0.0s
# [CV 5/10] END C=0.1, fit_intercept=False, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.722, test=0.810) total time=   0.0s
# [CV 6/10] END C=0.1, fit_intercept=False, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.727, test=0.762) total time=   0.0s
# [CV 7/10] END C=0.1, fit_intercept=False, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.711, test=0.524) total time=   0.0s
# [CV 8/10] END C=0.1, fit_intercept=False, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.733, test=0.762) total time=   0.0s
# [CV 9/10] END C=0.1, fit_intercept=False, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.750, test=0.700) total time=   0.0s
# [CV 10/10] END C=0.1, fit_intercept=False, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.718, test=0.750) total time=   0.0s
# [CV 1/10] END C=0.1, fit_intercept=False, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.738, test=0.762) total time=   0.0s
# [CV 2/10] END C=0.1, fit_intercept=False, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.727, test=0.714) total time=   0.0s
# [CV 3/10] END C=0.1, fit_intercept=False, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.701, test=0.619) total time=   0.0s
# [CV 4/10] END C=0.1, fit_intercept=False, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.738, test=0.571) total time=   0.0s
# [CV 5/10] END C=0.1, fit_intercept=False, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.722, test=0.810) total time=   0.0s
# [CV 6/10] END C=0.1, fit_intercept=False, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.727, test=0.762) total time=   0.0s
# [CV 7/10] END C=0.1, fit_intercept=False, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.711, test=0.524) total time=   0.0s
# [CV 8/10] END C=0.1, fit_intercept=False, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.733, test=0.762) total time=   0.0s
# [CV 9/10] END C=0.1, fit_intercept=False, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.750, test=0.700) total time=   0.0s
# [CV 10/10] END C=0.1, fit_intercept=False, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.718, test=0.750) total time=   0.0s
# [CV 1/10] END C=1, fit_intercept=True, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.829, test=0.810) total time=   0.0s
# [CV 2/10] END C=1, fit_intercept=True, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.807, test=0.762) total time=   0.0s
# [CV 3/10] END C=1, fit_intercept=True, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.834, test=0.762) total time=   0.0s
# [CV 4/10] END C=1, fit_intercept=True, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.813, test=0.571) total time=   0.0s
# [CV 5/10] END C=1, fit_intercept=True, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.840, test=0.810) total time=   0.0s
# [CV 6/10] END C=1, fit_intercept=True, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.807, test=0.857) total time=   0.0s
# [CV 7/10] END C=1, fit_intercept=True, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.802, test=0.857) total time=   0.0s
# [CV 8/10] END C=1, fit_intercept=True, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.797, test=0.952) total time=   0.0s
# [CV 9/10] END C=1, fit_intercept=True, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.846, test=0.700) total time=   0.0s
# [CV 10/10] END C=1, fit_intercept=True, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.803, test=0.750) total time=   0.0s
# [CV 1/10] END C=1, fit_intercept=True, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.829, test=0.810) total time=   0.0s
# [CV 2/10] END C=1, fit_intercept=True, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.807, test=0.762) total time=   0.0s
# [CV 3/10] END C=1, fit_intercept=True, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.834, test=0.762) total time=   0.0s
# [CV 4/10] END C=1, fit_intercept=True, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.813, test=0.571) total time=   0.0s
# [CV 5/10] END C=1, fit_intercept=True, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.840, test=0.810) total time=   0.0s
# [CV 6/10] END C=1, fit_intercept=True, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.807, test=0.857) total time=   0.0s
# [CV 7/10] END C=1, fit_intercept=True, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.802, test=0.857) total time=   0.0s
# [CV 8/10] END C=1, fit_intercept=True, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.797, test=0.952) total time=   0.0s
# [CV 9/10] END C=1, fit_intercept=True, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.846, test=0.700) total time=   0.0s
# [CV 10/10] END C=1, fit_intercept=True, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.803, test=0.750) total time=   0.0s
# [CV 1/10] END C=1, fit_intercept=True, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.829, test=0.810) total time=   0.0s
# [CV 2/10] END C=1, fit_intercept=True, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.807, test=0.762) total time=   0.0s
# [CV 3/10] END C=1, fit_intercept=True, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.834, test=0.762) total time=   0.0s
# [CV 4/10] END C=1, fit_intercept=True, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.813, test=0.571) total time=   0.0s
# [CV 5/10] END C=1, fit_intercept=True, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.840, test=0.810) total time=   0.0s
# [CV 6/10] END C=1, fit_intercept=True, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.807, test=0.857) total time=   0.0s
# [CV 7/10] END C=1, fit_intercept=True, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.802, test=0.857) total time=   0.0s
# [CV 8/10] END C=1, fit_intercept=True, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.797, test=0.952) total time=   0.0s
# [CV 9/10] END C=1, fit_intercept=True, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.846, test=0.700) total time=   0.0s
# [CV 10/10] END C=1, fit_intercept=True, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.803, test=0.750) total time=   0.0s
# [CV 1/10] END C=1, fit_intercept=True, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.829, test=0.810) total time=   0.0s
# [CV 2/10] END C=1, fit_intercept=True, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.807, test=0.762) total time=   0.0s
# [CV 3/10] END C=1, fit_intercept=True, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.834, test=0.762) total time=   0.0s
# [CV 4/10] END C=1, fit_intercept=True, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.813, test=0.571) total time=   0.0s
# [CV 5/10] END C=1, fit_intercept=True, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.840, test=0.810) total time=   0.0s
# [CV 6/10] END C=1, fit_intercept=True, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.807, test=0.857) total time=   0.0s
# [CV 7/10] END C=1, fit_intercept=True, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.802, test=0.857) total time=   0.0s
# [CV 8/10] END C=1, fit_intercept=True, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.797, test=0.952) total time=   0.0s
# [CV 9/10] END C=1, fit_intercept=True, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.846, test=0.700) total time=   0.0s
# [CV 10/10] END C=1, fit_intercept=True, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.803, test=0.750) total time=   0.0s
# [CV 1/10] END C=1, fit_intercept=True, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.829, test=0.810) total time=   0.0s
# [CV 2/10] END C=1, fit_intercept=True, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.807, test=0.762) total time=   0.0s
# [CV 3/10] END C=1, fit_intercept=True, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.834, test=0.762) total time=   0.0s
# [CV 4/10] END C=1, fit_intercept=True, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.813, test=0.571) total time=   0.0s
# [CV 5/10] END C=1, fit_intercept=True, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.840, test=0.810) total time=   0.0s
# [CV 6/10] END C=1, fit_intercept=True, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.807, test=0.857) total time=   0.0s
# [CV 7/10] END C=1, fit_intercept=True, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.802, test=0.857) total time=   0.0s
# [CV 8/10] END C=1, fit_intercept=True, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.797, test=0.952) total time=   0.0s
# [CV 9/10] END C=1, fit_intercept=True, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.846, test=0.700) total time=   0.0s
# [CV 10/10] END C=1, fit_intercept=True, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.803, test=0.750) total time=   0.0s
# [CV 1/10] END C=1, fit_intercept=True, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.829, test=0.810) total time=   0.0s
# [CV 2/10] END C=1, fit_intercept=True, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.807, test=0.762) total time=   0.0s
# [CV 3/10] END C=1, fit_intercept=True, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.834, test=0.762) total time=   0.0s
# [CV 4/10] END C=1, fit_intercept=True, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.813, test=0.571) total time=   0.0s
# [CV 5/10] END C=1, fit_intercept=True, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.840, test=0.810) total time=   0.0s
# [CV 6/10] END C=1, fit_intercept=True, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.807, test=0.857) total time=   0.0s
# [CV 7/10] END C=1, fit_intercept=True, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.802, test=0.857) total time=   0.0s
# [CV 8/10] END C=1, fit_intercept=True, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.797, test=0.952) total time=   0.0s
# [CV 9/10] END C=1, fit_intercept=True, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.846, test=0.700) total time=   0.0s
# [CV 10/10] END C=1, fit_intercept=True, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.803, test=0.750) total time=   0.0s
# [CV 1/10] END C=1, fit_intercept=True, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.829, test=0.810) total time=   0.0s
# [CV 2/10] END C=1, fit_intercept=True, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.807, test=0.762) total time=   0.0s
# [CV 3/10] END C=1, fit_intercept=True, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.834, test=0.762) total time=   0.0s
# [CV 4/10] END C=1, fit_intercept=True, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.813, test=0.571) total time=   0.0s
# [CV 5/10] END C=1, fit_intercept=True, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.840, test=0.810) total time=   0.0s
# [CV 6/10] END C=1, fit_intercept=True, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.807, test=0.857) total time=   0.0s
# [CV 7/10] END C=1, fit_intercept=True, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.802, test=0.857) total time=   0.0s
# [CV 8/10] END C=1, fit_intercept=True, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.797, test=0.952) total time=   0.0s
# [CV 9/10] END C=1, fit_intercept=True, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.846, test=0.700) total time=   0.0s
# [CV 10/10] END C=1, fit_intercept=True, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.803, test=0.750) total time=   0.0s
# [CV 1/10] END C=1, fit_intercept=True, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.829, test=0.810) total time=   0.0s
# [CV 2/10] END C=1, fit_intercept=True, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.807, test=0.762) total time=   0.0s
# [CV 3/10] END C=1, fit_intercept=True, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.834, test=0.762) total time=   0.0s
# [CV 4/10] END C=1, fit_intercept=True, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.813, test=0.571) total time=   0.0s
# [CV 5/10] END C=1, fit_intercept=True, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.840, test=0.810) total time=   0.0s
# [CV 6/10] END C=1, fit_intercept=True, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.807, test=0.857) total time=   0.0s
# [CV 7/10] END C=1, fit_intercept=True, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.802, test=0.857) total time=   0.0s
# [CV 8/10] END C=1, fit_intercept=True, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.797, test=0.952) total time=   0.0s
# [CV 9/10] END C=1, fit_intercept=True, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.846, test=0.700) total time=   0.0s
# [CV 10/10] END C=1, fit_intercept=True, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.803, test=0.750) total time=   0.0s
# [CV 1/10] END C=1, fit_intercept=True, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.829, test=0.810) total time=   0.0s
# [CV 2/10] END C=1, fit_intercept=True, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.807, test=0.762) total time=   0.0s
# [CV 3/10] END C=1, fit_intercept=True, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.834, test=0.762) total time=   0.0s
# [CV 4/10] END C=1, fit_intercept=True, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.813, test=0.571) total time=   0.0s
# [CV 5/10] END C=1, fit_intercept=True, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.840, test=0.810) total time=   0.0s
# [CV 6/10] END C=1, fit_intercept=True, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.807, test=0.857) total time=   0.0s
# [CV 7/10] END C=1, fit_intercept=True, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.802, test=0.857) total time=   0.0s
# [CV 8/10] END C=1, fit_intercept=True, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.797, test=0.952) total time=   0.0s
# [CV 9/10] END C=1, fit_intercept=True, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.846, test=0.700) total time=   0.0s
# [CV 10/10] END C=1, fit_intercept=True, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.803, test=0.750) total time=   0.0s
# [CV 1/10] END C=1, fit_intercept=True, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.829, test=0.810) total time=   0.0s
# [CV 2/10] END C=1, fit_intercept=True, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.807, test=0.762) total time=   0.0s
# [CV 3/10] END C=1, fit_intercept=True, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.834, test=0.762) total time=   0.0s
# [CV 4/10] END C=1, fit_intercept=True, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.813, test=0.571) total time=   0.0s
# [CV 5/10] END C=1, fit_intercept=True, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.840, test=0.810) total time=   0.0s
# [CV 6/10] END C=1, fit_intercept=True, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.807, test=0.857) total time=   0.0s
# [CV 7/10] END C=1, fit_intercept=True, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.802, test=0.857) total time=   0.0s
# [CV 8/10] END C=1, fit_intercept=True, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.797, test=0.952) total time=   0.0s
# [CV 9/10] END C=1, fit_intercept=True, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.846, test=0.700) total time=   0.0s
# [CV 10/10] END C=1, fit_intercept=True, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.803, test=0.750) total time=   0.0s
# [CV 1/10] END C=1, fit_intercept=False, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.829, test=0.810) total time=   0.0s
# [CV 2/10] END C=1, fit_intercept=False, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.807, test=0.762) total time=   0.0s
# [CV 3/10] END C=1, fit_intercept=False, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.834, test=0.762) total time=   0.0s
# [CV 4/10] END C=1, fit_intercept=False, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.813, test=0.571) total time=   0.0s
# [CV 5/10] END C=1, fit_intercept=False, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.840, test=0.810) total time=   0.0s
# [CV 6/10] END C=1, fit_intercept=False, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.807, test=0.857) total time=   0.0s
# [CV 7/10] END C=1, fit_intercept=False, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.802, test=0.857) total time=   0.0s
# [CV 8/10] END C=1, fit_intercept=False, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.797, test=0.952) total time=   0.0s
# [CV 9/10] END C=1, fit_intercept=False, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.846, test=0.700) total time=   0.0s
# [CV 10/10] END C=1, fit_intercept=False, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.803, test=0.750) total time=   0.0s
# [CV 1/10] END C=1, fit_intercept=False, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.829, test=0.810) total time=   0.0s
# [CV 2/10] END C=1, fit_intercept=False, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.807, test=0.762) total time=   0.0s
# [CV 3/10] END C=1, fit_intercept=False, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.834, test=0.762) total time=   0.0s
# [CV 4/10] END C=1, fit_intercept=False, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.813, test=0.571) total time=   0.0s
# [CV 5/10] END C=1, fit_intercept=False, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.840, test=0.810) total time=   0.0s
# [CV 6/10] END C=1, fit_intercept=False, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.807, test=0.857) total time=   0.0s
# [CV 7/10] END C=1, fit_intercept=False, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.802, test=0.857) total time=   0.0s
# [CV 8/10] END C=1, fit_intercept=False, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.797, test=0.952) total time=   0.0s
# [CV 9/10] END C=1, fit_intercept=False, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.846, test=0.700) total time=   0.0s
# [CV 10/10] END C=1, fit_intercept=False, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.803, test=0.750) total time=   0.0s
# [CV 1/10] END C=1, fit_intercept=False, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.829, test=0.810) total time=   0.0s
# [CV 2/10] END C=1, fit_intercept=False, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.807, test=0.762) total time=   0.0s
# [CV 3/10] END C=1, fit_intercept=False, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.834, test=0.762) total time=   0.0s
# [CV 4/10] END C=1, fit_intercept=False, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.813, test=0.571) total time=   0.0s
# [CV 5/10] END C=1, fit_intercept=False, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.840, test=0.810) total time=   0.0s
# [CV 6/10] END C=1, fit_intercept=False, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.807, test=0.857) total time=   0.0s
# [CV 7/10] END C=1, fit_intercept=False, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.802, test=0.857) total time=   0.0s
# [CV 8/10] END C=1, fit_intercept=False, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.797, test=0.952) total time=   0.0s
# [CV 9/10] END C=1, fit_intercept=False, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.846, test=0.700) total time=   0.0s
# [CV 10/10] END C=1, fit_intercept=False, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.803, test=0.750) total time=   0.0s
# [CV 1/10] END C=1, fit_intercept=False, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.829, test=0.810) total time=   0.0s
# [CV 2/10] END C=1, fit_intercept=False, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.807, test=0.762) total time=   0.0s
# [CV 3/10] END C=1, fit_intercept=False, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.834, test=0.762) total time=   0.0s
# [CV 4/10] END C=1, fit_intercept=False, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.813, test=0.571) total time=   0.0s
# [CV 5/10] END C=1, fit_intercept=False, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.840, test=0.810) total time=   0.0s
# [CV 6/10] END C=1, fit_intercept=False, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.807, test=0.857) total time=   0.0s
# [CV 7/10] END C=1, fit_intercept=False, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.802, test=0.857) total time=   0.0s
# ...
# [CV 3/10] END C=20, fit_intercept=True, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.882, test=0.619) total time=   0.0s
# [CV 4/10] END C=20, fit_intercept=True, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.882, test=0.810) total time=   0.0s
# [CV 5/10] END C=20, fit_intercept=True, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.877, test=0.714) total time=   0.0s
# [CV 6/10] END C=20, fit_intercept=True, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.872, test=0.810) total time=   0.0s
# [CV 7/10] END C=20, fit_intercept=True, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.882, test=0.762) total time=   0.0s
# [CV 8/10] END C=20, fit_intercept=True, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.866, test=0.857) total time=   0.0s
# [CV 9/10] END C=20, fit_intercept=True, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.883, test=0.700) total time=   0.0s
# [CV 10/10] END C=20, fit_intercept=True, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.867, test=0.700) total time=   0.0s
# [CV 1/10] END C=20, fit_intercept=False, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.861, test=0.905) total time=   0.0s
# [CV 2/10] END C=20, fit_intercept=False, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.877, test=0.810) total time=   0.0s
# [CV 3/10] END C=20, fit_intercept=False, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.882, test=0.619) total time=   0.0s
# [CV 4/10] END C=20, fit_intercept=False, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.882, test=0.810) total time=   0.0s
# [CV 5/10] END C=20, fit_intercept=False, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.877, test=0.714) total time=   0.0s
# [CV 6/10] END C=20, fit_intercept=False, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.872, test=0.810) total time=   0.0s
# [CV 7/10] END C=20, fit_intercept=False, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.882, test=0.762) total time=   0.0s
# [CV 8/10] END C=20, fit_intercept=False, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.866, test=0.857) total time=   0.0s
# [CV 9/10] END C=20, fit_intercept=False, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.883, test=0.700) total time=   0.0s
# [CV 10/10] END C=20, fit_intercept=False, max_iter=10, multi_class=auto, solver=liblinear;, score=(train=0.867, test=0.700) total time=   0.0s
# [CV 1/10] END C=20, fit_intercept=False, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.861, test=0.905) total time=   0.0s
# [CV 2/10] END C=20, fit_intercept=False, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.877, test=0.810) total time=   0.0s
# [CV 3/10] END C=20, fit_intercept=False, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.882, test=0.619) total time=   0.0s
# [CV 4/10] END C=20, fit_intercept=False, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.882, test=0.810) total time=   0.0s
# [CV 5/10] END C=20, fit_intercept=False, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.877, test=0.714) total time=   0.0s
# [CV 6/10] END C=20, fit_intercept=False, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.872, test=0.810) total time=   0.0s
# [CV 7/10] END C=20, fit_intercept=False, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.882, test=0.762) total time=   0.0s
# [CV 8/10] END C=20, fit_intercept=False, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.866, test=0.857) total time=   0.0s
# [CV 9/10] END C=20, fit_intercept=False, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.883, test=0.700) total time=   0.0s
# [CV 10/10] END C=20, fit_intercept=False, max_iter=10, multi_class=ovr, solver=liblinear;, score=(train=0.867, test=0.700) total time=   0.0s
# [CV 1/10] END C=20, fit_intercept=False, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.861, test=0.905) total time=   0.0s
# [CV 2/10] END C=20, fit_intercept=False, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.877, test=0.810) total time=   0.0s
# [CV 3/10] END C=20, fit_intercept=False, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.882, test=0.619) total time=   0.0s
# [CV 4/10] END C=20, fit_intercept=False, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.882, test=0.810) total time=   0.0s
# [CV 5/10] END C=20, fit_intercept=False, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.877, test=0.714) total time=   0.0s
# [CV 6/10] END C=20, fit_intercept=False, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.872, test=0.810) total time=   0.0s
# [CV 7/10] END C=20, fit_intercept=False, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.882, test=0.762) total time=   0.0s
# [CV 8/10] END C=20, fit_intercept=False, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.866, test=0.857) total time=   0.0s
# [CV 9/10] END C=20, fit_intercept=False, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.883, test=0.700) total time=   0.0s
# [CV 10/10] END C=20, fit_intercept=False, max_iter=100, multi_class=auto, solver=liblinear;, score=(train=0.867, test=0.700) total time=   0.0s
# [CV 1/10] END C=20, fit_intercept=False, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.861, test=0.905) total time=   0.0s
# [CV 2/10] END C=20, fit_intercept=False, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.877, test=0.810) total time=   0.0s
# [CV 3/10] END C=20, fit_intercept=False, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.882, test=0.619) total time=   0.0s
# [CV 4/10] END C=20, fit_intercept=False, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.882, test=0.810) total time=   0.0s
# [CV 5/10] END C=20, fit_intercept=False, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.877, test=0.714) total time=   0.0s
# [CV 6/10] END C=20, fit_intercept=False, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.872, test=0.810) total time=   0.0s
# [CV 7/10] END C=20, fit_intercept=False, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.882, test=0.762) total time=   0.0s
# [CV 8/10] END C=20, fit_intercept=False, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.866, test=0.857) total time=   0.0s
# [CV 9/10] END C=20, fit_intercept=False, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.883, test=0.700) total time=   0.0s
# [CV 10/10] END C=20, fit_intercept=False, max_iter=100, multi_class=ovr, solver=liblinear;, score=(train=0.867, test=0.700) total time=   0.0s
# [CV 1/10] END C=20, fit_intercept=False, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.861, test=0.905) total time=   0.0s
# [CV 2/10] END C=20, fit_intercept=False, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.877, test=0.810) total time=   0.0s
# [CV 3/10] END C=20, fit_intercept=False, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.882, test=0.619) total time=   0.0s
# [CV 4/10] END C=20, fit_intercept=False, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.882, test=0.810) total time=   0.0s
# [CV 5/10] END C=20, fit_intercept=False, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.877, test=0.714) total time=   0.0s
# [CV 6/10] END C=20, fit_intercept=False, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.872, test=0.810) total time=   0.0s
# [CV 7/10] END C=20, fit_intercept=False, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.882, test=0.762) total time=   0.0s
# [CV 8/10] END C=20, fit_intercept=False, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.866, test=0.857) total time=   0.0s
# [CV 9/10] END C=20, fit_intercept=False, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.883, test=0.700) total time=   0.0s
# [CV 10/10] END C=20, fit_intercept=False, max_iter=200, multi_class=auto, solver=liblinear;, score=(train=0.867, test=0.700) total time=   0.0s
# [CV 1/10] END C=20, fit_intercept=False, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.861, test=0.905) total time=   0.0s
# [CV 2/10] END C=20, fit_intercept=False, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.877, test=0.810) total time=   0.0s
# [CV 3/10] END C=20, fit_intercept=False, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.882, test=0.619) total time=   0.0s
# [CV 4/10] END C=20, fit_intercept=False, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.882, test=0.810) total time=   0.0s
# [CV 5/10] END C=20, fit_intercept=False, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.877, test=0.714) total time=   0.0s
# [CV 6/10] END C=20, fit_intercept=False, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.872, test=0.810) total time=   0.0s
# [CV 7/10] END C=20, fit_intercept=False, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.882, test=0.762) total time=   0.0s
# [CV 8/10] END C=20, fit_intercept=False, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.866, test=0.857) total time=   0.0s
# [CV 9/10] END C=20, fit_intercept=False, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.883, test=0.700) total time=   0.0s
# [CV 10/10] END C=20, fit_intercept=False, max_iter=200, multi_class=ovr, solver=liblinear;, score=(train=0.867, test=0.700) total time=   0.0s
# [CV 1/10] END C=20, fit_intercept=False, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.861, test=0.905) total time=   0.0s
# [CV 2/10] END C=20, fit_intercept=False, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.877, test=0.810) total time=   0.0s
# [CV 3/10] END C=20, fit_intercept=False, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.882, test=0.619) total time=   0.0s
# [CV 4/10] END C=20, fit_intercept=False, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.882, test=0.810) total time=   0.0s
# [CV 5/10] END C=20, fit_intercept=False, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.877, test=0.714) total time=   0.0s
# [CV 6/10] END C=20, fit_intercept=False, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.872, test=0.810) total time=   0.0s
# [CV 7/10] END C=20, fit_intercept=False, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.882, test=0.762) total time=   0.0s
# [CV 8/10] END C=20, fit_intercept=False, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.866, test=0.857) total time=   0.0s
# [CV 9/10] END C=20, fit_intercept=False, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.883, test=0.700) total time=   0.0s
# [CV 10/10] END C=20, fit_intercept=False, max_iter=500, multi_class=auto, solver=liblinear;, score=(train=0.867, test=0.700) total time=   0.0s
# [CV 1/10] END C=20, fit_intercept=False, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.861, test=0.905) total time=   0.0s
# [CV 2/10] END C=20, fit_intercept=False, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.877, test=0.810) total time=   0.0s
# [CV 3/10] END C=20, fit_intercept=False, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.882, test=0.619) total time=   0.0s
# [CV 4/10] END C=20, fit_intercept=False, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.882, test=0.810) total time=   0.0s
# [CV 5/10] END C=20, fit_intercept=False, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.877, test=0.714) total time=   0.0s
# [CV 6/10] END C=20, fit_intercept=False, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.872, test=0.810) total time=   0.0s
# [CV 7/10] END C=20, fit_intercept=False, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.882, test=0.762) total time=   0.0s
# [CV 8/10] END C=20, fit_intercept=False, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.866, test=0.857) total time=   0.0s
# [CV 9/10] END C=20, fit_intercept=False, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.883, test=0.700) total time=   0.0s
# [CV 10/10] END C=20, fit_intercept=False, max_iter=500, multi_class=ovr, solver=liblinear;, score=(train=0.867, test=0.700) total time=   0.0s
# [CV 1/10] END C=20, fit_intercept=False, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.861, test=0.905) total time=   0.0s
# [CV 2/10] END C=20, fit_intercept=False, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.877, test=0.810) total time=   0.0s
# [CV 3/10] END C=20, fit_intercept=False, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.882, test=0.619) total time=   0.0s
# [CV 4/10] END C=20, fit_intercept=False, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.882, test=0.810) total time=   0.0s
# [CV 5/10] END C=20, fit_intercept=False, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.877, test=0.714) total time=   0.0s
# [CV 6/10] END C=20, fit_intercept=False, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.872, test=0.810) total time=   0.0s
# [CV 7/10] END C=20, fit_intercept=False, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.882, test=0.762) total time=   0.0s
# [CV 8/10] END C=20, fit_intercept=False, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.866, test=0.857) total time=   0.0s
# [CV 9/10] END C=20, fit_intercept=False, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.883, test=0.700) total time=   0.0s
# [CV 10/10] END C=20, fit_intercept=False, max_iter=1000, multi_class=auto, solver=liblinear;, score=(train=0.867, test=0.700) total time=   0.0s
# [CV 1/10] END C=20, fit_intercept=False, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.861, test=0.905) total time=   0.0s
# [CV 2/10] END C=20, fit_intercept=False, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.877, test=0.810) total time=   0.0s
# [CV 3/10] END C=20, fit_intercept=False, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.882, test=0.619) total time=   0.0s
# [CV 4/10] END C=20, fit_intercept=False, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.882, test=0.810) total time=   0.0s
# [CV 5/10] END C=20, fit_intercept=False, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.877, test=0.714) total time=   0.0s
# [CV 6/10] END C=20, fit_intercept=False, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.872, test=0.810) total time=   0.0s
# [CV 7/10] END C=20, fit_intercept=False, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.882, test=0.762) total time=   0.0s
# [CV 8/10] END C=20, fit_intercept=False, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.866, test=0.857) total time=   0.0s
# [CV 9/10] END C=20, fit_intercept=False, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.883, test=0.700) total time=   0.0s
# [CV 10/10] END C=20, fit_intercept=False, max_iter=1000, multi_class=ovr, solver=liblinear;, score=(train=0.867, test=0.700) total time=   0.0s
# GridSearchCV(cv=KFold(n_splits=10, random_state=None, shuffle=True),
#              estimator=LogisticRegression(C=10, fit_intercept='True',
#                                           max_iter=10, solver='liblinear'),
#              param_grid=[{'C': [0.1, 1, 10, 15, 20],
#                           'fit_intercept': ['True', 'False'],
#                           'max_iter': [10, 100, 200, 500, 1000],
#                           'multi_class': ['auto', 'ovr'],
#                           'solver': ['liblinear']}],
#              return_train_score=True, scoring='accuracy', verbose=3)

# %%
# print estimator that was chosen by the GridSearch
print('\nEstimator that was chosen by the search:', gs.best_estimator_)

# mean cross-validated score of the best_estimator
print('\nMean cross-validated score of the best_estimator:', round(gs.best_score_, 4))

# Scorer function used on the held out data to choose the best parameters for the model
print('\nMean cross-validate score of GS:', round(gs.score(X, y), 4))
# Out:
# Estimator that was chosen by the search: LogisticRegression(C=10, fit_intercept='True', max_iter=10, solver='liblinear')
#
# Mean cross-validated score of the best_estimator: 0.7881
#
# Mean cross-validate score of GS: 0.8702

# %%
# select algorithm's parameters
model = LogisticRegression(C=10, fit_intercept='True', max_iter=10, solver='liblinear')
# select desired metrics
scoring = ['accuracy']
# calculate accuracy score
cv_scores = cross_validate(model, X, y, cv=kf,scoring=scoring,
                           return_train_score=True)

# %% [markdown]
# Check for **overfitting** issues via training and testing scores.

# %%
train_splits = []
test_splits = []
for key, value in cv_scores.items():
  if key == 'train_accuracy':
    train_splits.append(value)
  if key == 'test_accuracy':
    test_splits.append(value)

# set column names
split_cols_names = ['split 1', 'split 2', 'split 3', 'split 4', 'split 5',
                    'split 6', 'split 7', 'split 8', 'split 9', 'split 10']

# convert lists of scores to dataframe
train_scores = pd.DataFrame(train_splits, columns=split_cols_names)
test_scores = pd.DataFrame(test_splits, columns=split_cols_names)

# rename rows
train_scores.rename(index = {0: "Accuracy (Train)"}, inplace = True)
test_scores.rename(index = {0: "Accuracy (Test)"}, inplace = True)

# merge both dataframes into a single one
data = train_scores.append(test_scores)

# calculate mean scores
mean_scores = data.mean(axis=1)

# append column to the dataframe
data['mean'] = round(mean_scores, 4)
# display dataframe as a tables
display(data)
# Out:
#                    split 1   split 2   split 3  ...   split 9  split 10    mean
# Accuracy (Train)  0.866310  0.887701  0.887701  ...  0.882979  0.845745  0.8659
# Accuracy (Test)   0.714286  0.714286  0.761905  ...  0.700000  0.850000  0.7693
#
# [2 rows x 11 columns]

# %% [markdown]
# <a name="CM"> </a>
# Generate a **Confusion Matrix**:

# %%
# predict using cross validation
y_pred = cross_val_predict(model, X, y, cv=kf)
# generate the confusion matrix
cm = confusion_matrix(y, y_pred)
# visualize confusion matrix with seaborn heatmap
cm_matrix = pd.DataFrame(data=cm, columns=['Actual Positive:1',
                                           'Actual Negative:0'],
                        index=['Predict Positive:1', 'Predict Negative:0'])
fig, ax = plt.subplots(figsize=(7,7))  
sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')
